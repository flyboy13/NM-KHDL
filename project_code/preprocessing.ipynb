# %% [markdown]
# <h1><b>PHẦN 1: QUY TRÌNH KHOA HỌC DỮ LIỆU</b></h1>

# %% [markdown]
# <h1><b>A. Thu thập dữ liệu (Data collection)</b></h1>

# %% [markdown]
# ## Import những thư viện cần thiết

# %%
import scrapy
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ## Tạo một project mới với scrapy
#
# Bắt đầu tạo một project mới với scrapy với tên gọi là <b>"colect_data"</b>.

# %%
# !scrapy startproject colect_data
# Out:
# Error: scrapy.cfg already exists in c:\Users\HP\OneDrive - VNU-HCMUS\Documents\GitHub\NM-KHDL\project_code\colect_data

# %%
cd colect_data/colect_data
# Out:
# c:\Users\HP\OneDrive - VNU-HCMUS\Documents\GitHub\NM-KHDL\project_code\colect_data\colect_data

# %% [markdown]
# Sau khi tạo xong project với scrapy, ta cần tạo một file có tên <b>collect_data.py</b> vào đường dẫn sau <b>collect_data/collect_data/spiders/collect_data.py</b>. Su đó chạy lệnh sau để thu thập dữ liệu.

# %%
# !scrapy crawl Get_Data -o dataset/inf.csv
# Out:
# 2022-11-29 16:04:41 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: colect_data)
# 2022-11-29 16:04:41 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.0.1, Twisted 22.10.0, Python 3.10.8 (tags/v3.10.8:aaaf517, Oct 11 2022, 16:50:30) [MSC v.1933 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.3, Platform Windows-10-10.0.19044-SP0
# 2022-11-29 16:04:41 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'colect_data',
#  'NEWSPIDER_MODULE': 'colect_data.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['colect_data.spiders']}
# 2022-11-29 16:04:41 [py.warnings] WARNING: C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2022-11-29 16:04:41 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-11-29 16:04:42 [scrapy.extensions.telnet] INFO: Telnet Password: 3d48598863d741e1
# 2022-11-29 16:04:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-11-29 16:04:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-11-29 16:04:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-11-29 16:04:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-11-29 16:04:42 [scrapy.core.engine] INFO: Spider opened
# 2022-11-29 16:04:43 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-11-29 16:04:43 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-11-29 16:04:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/robots.txt> (referer: None)
# 2022-11-29 16:04:44 [filelock] DEBUG: Attempting to acquire lock 2366421742976 on C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-11-29 16:04:44 [filelock] DEBUG: Lock 2366421742976 acquired on C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-11-29 16:04:44 [filelock] DEBUG: Attempting to release lock 2366421742976 on C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-11-29 16:04:44 [filelock] DEBUG: Lock 2366421742976 released on C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-11-29 16:04:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1> (referer: None)
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2122158', 'Title': 'Thuê phòng 2.5 triệu 20m2 căn bìa tầng trệt gần nhà hàng Riverside Q4', 'Price': '2.5 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 4', 'City': 'Hồ Chí Minh', 'Date': '\n29/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2119311', 'Title': 'Cho thuê phòng ĐẸP 16m2 đường Thành Thái-Q10, có chỗ để xe, giá rẻ', 'Price': '5 Triệu/tháng ', 'Square': '16m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n25/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2118730', 'Title': 'Cho thuê giường kén CAPSULE CAO CẤP SMART _ Trung tâm Q.3', 'Price': '2.8 Triệu/tháng ', 'Square': '30m²', 'District': 'Quận 3', 'City': 'Hồ Chí Minh', 'Date': '\n24/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2113773', 'Title': 'Cho thuê phòng trọ tại phường 12 - gò vấp', 'Price': '5.5 Triệu/tháng ', 'Square': '20m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n17/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2112161', 'Title': 'Nhà mới xây, Miễn phí cầu thang máy, điều hòa, Wife, SDT chủ nhà 0986.77.22.77', 'Price': '2.8 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n15/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2111349', 'Title': 'Phòng trọ giá rẻ quận 12, đủ 3-4 người ở, có gác giá chỉ 3.1 triệu.', 'Price': '3.1 Triệu/tháng ', 'Square': '15m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n14/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2111350', 'Title': 'Phòng trọ gò vấp có ban công và nội thất chỉ 3tr6, tin được không !!!', 'Price': '3.6 Triệu/tháng ', 'Square': '15m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n14/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2111362', 'Title': 'Phòng cho thuê quận Bình Thạnh, đường Ung Văn Khiêm', 'Price': '4 Triệu/tháng ', 'Square': '28m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n14/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2109867', 'Title': 'Căn hộ đẹp Tràn Ngập Tiện Nghi ngay trung tâm Q.1', 'Price': '6 Triệu/tháng ', 'Square': '30m²', 'District': 'Quận 1', 'City': 'Hồ Chí Minh', 'Date': '\n12/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2110131', 'Title': 'Cho thuê phòng full nội thất giá tốt- phòng trống ở ngay.', 'Price': '4.5 Triệu/tháng ', 'Square': '20m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n12/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2109043', 'Title': 'Căn hộ 2T bancony ngay chợ Bà Chiểu, sát hàng xanh, tiện đi Hutech, UEF, Hồng Bàng', 'Price': '6.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n11/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '1628369', 'Title': 'Cho Thuê Phòng Trọ Giá Bình Dân, Quận Tân Bình, TP. Hồ Chí Minh', 'Price': '1 Triệu/tháng ', 'Square': '8m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n11/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2108731', 'Title': 'Cho Thuê 2 PHÒNG TRỌ tại số 63/5 Phan Tây Hồ, P.7, Q. Phú Nhuận', 'Price': '5.5 Triệu/tháng ', 'Square': '33m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n10/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2105703', 'Title': 'Cho thuê phòng trọ đủ nội thất, giá chỉ 2tr8.', 'Price': '2.8 Triệu/tháng ', 'Square': '12m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n07/11/2022 '}
# 2022-11-29 16:04:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1>
#
# {'Id': '2105755', 'Title': 'Cho thuê phòng trọ bình chiểu,thủ đức ,khu cn sóng thần (có gác lửng, phòng vệ sinh trong phòng)', 'Price': '1 Triệu/tháng ', 'Square': '12m²', 'District': 'Thủ Đức', 'City': 'Hồ Chí Minh', 'Date': '\n07/11/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t1)
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2095028', 'Title': 'Phòng Ký túc xá Sát Đ.H Công Nghiệp Thực Phẩm', 'Price': '1.35 Triệu/tháng ', 'Square': '25m²', 'District': 'Tân Phú', 'City': 'Hồ Chí Minh', 'Date': '\n25/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2094225', 'Title': 'Cho thuê phòng trọ có gác giá rẻ nhưng đầy đủ tiện ích và dịch vụ!!!', 'Price': '3.7 Triệu/tháng ', 'Square': '15m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n24/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2063757', 'Title': 'Cho Thuê Phòng Đường Mai Văn Vĩnh, Quận 7, Ban Công Thoáng Mát!!!', 'Price': '4 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n17/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2062577', 'Title': 'Cho Thuê Phòng Ở Đường Số 51, Tân Quy, Quận 7', 'Price': '4 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n16/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2085692', 'Title': 'Căn hộ dịch vụ mới khai trương, ngay trong KDC Phong Phú 4 huỵện bình chánh', 'Price': '4 Triệu/tháng ', 'Square': '30m²', 'District': 'Bình Chánh', 'City': 'Hồ Chí Minh', 'Date': '\n13/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2083942', 'Title': 'Cho thuê phòng KDC Trung Sơn 35-45m2. Hoặc nguyên tầng làm văn phòng đaị diện', 'Price': '8 Triệu/tháng ', 'Square': '40m²', 'District': 'Bình Chánh', 'City': 'Hồ Chí Minh', 'Date': '\n11/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2076676', 'Title': 'CHDV Giaỉ Phóng Tân Bình có gác,ban công chỉ 5tr8.', 'Price': '5.8 Triệu/tháng ', 'Square': '30m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n03/10/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2066592', 'Title': 'Cho thuê phòng trọ ở 28 tự lập, phường 4 , quận tân bình ,tp hcm.', 'Price': '5.3 Triệu/tháng ', 'Square': '40m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n21/09/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2065600', 'Title': 'Phòng trọ ký túc xá quận phú nhuận 700k bao trọn gói', 'Price': '0.7 Triệu/tháng ', 'Square': '25m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n20/09/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2060596', 'Title': 'Cho thuê phòng mới đường Xuân Thới Sơn 27-Hóc Môn, 26m2-1.6tr/tháng', 'Price': '1.6 Triệu/tháng ', 'Square': '26m²', 'District': 'Hóc Môn', 'City': 'Hồ Chí Minh', 'Date': '\n14/09/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2040637', 'Title': 'Cho thuê phòng ĐẸP gần Đầm Sen và nhà thi đấu Phú Thọ, GIÁ RẺ nhất KV', 'Price': '1.5 Triệu/tháng ', 'Square': '15m²', 'District': 'Quận 11', 'City': 'Hồ Chí Minh', 'Date': '\n 22/08/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2039541', 'Title': 'Phòng trọ nội thất tiện nghi Hà Thị Khiêm Lê Thị Nho CVPM Quang Trung Q12', 'Price': '3.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n20/08/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2038120', 'Title': 'Cho thuê phòng trần q.thảo,q3. 2.2tr/tháng', 'Price': '2.2 Triệu/tháng ', 'Square': '16m²', 'District': 'Quận 3', 'City': 'Hồ Chí Minh', 'Date': '\n19/08/2022  '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2038230', 'Title': 'Căn hộ mini cao cấp full nội thất tại Quận 1', 'Price': '5 Triệu/tháng ', 'Square': '25m²', 'District': 'Quận 1', 'City': 'Hồ Chí Minh', 'Date': '\n19/08/2022 '}
# 2022-11-29 16:04:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2>
#
# {'Id': '2037208', 'Title': 'Phòng trọ 1,4tr/thang Sát bên đại học kinh tế Q10', 'Price': '1.4 Triệu/tháng ', 'Square': '35m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n18/08/2022 '}
# 2022-11-29 16:04:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t2)
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023597', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH', 'Price': '5.5 Triệu/tháng ', 'Square': '35m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023601', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH P.25, P.22, P.24', 'Price': '4 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023611', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH khu vực P.25, P.22', 'Price': '3.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023615', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH khu vực P.25', 'Price': '3.2 Triệu/tháng ', 'Square': '20m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023619', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH khu vực P.22', 'Price': '6 Triệu/tháng ', 'Square': '37m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2023623', 'Title': 'Phòng trọ Bình Thạnh thuận tiện cho sinh viên gần nhiều trường ĐH Hutech, Ngoại thương, GTVT...', 'Price': '4.9 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n04/08/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2017154', 'Title': 'Cho thuê phòng trọ giá bình dân phường 5, quận tân bình, giá 1,8tr.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n28/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2017155', 'Title': 'Phòng trọ phạm văn hai, quận tân bình, giá 1,8 triệu.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n28/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2017158', 'Title': 'Phòng trọ giáp hoàng sa, trường sa, quận tân bình, giá rẻ.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n28/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2016530', 'Title': 'Cho thuê phòng ở đường điện biên phủ, quận bình thạnh', 'Price': '2.3 Triệu/tháng ', 'Square': '12m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n27/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2015975', 'Title': 'Phòng lầu đúc tại Bình Thạnh giá 1tr8 chung chủ', 'Price': '1.8 Triệu/tháng ', 'Square': '20m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n27/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2014113', 'Title': 'Cho thuê phòng ĐẸP đường Cô Giang-Q1, 20m2 có gác rộng (ở 4-5 người)', 'Price': '5 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 1', 'City': 'Hồ Chí Minh', 'Date': '\n25/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2014152', 'Title': 'Cho thuê mặt bằng KD và phòng trọ Nguyễn Gia Trí, Bình Thạnh, giá tốt', 'Price': '5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n25/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '2013218', 'Title': 'Cho Thuê phòng trọ giá rẻ tiện ích wifi, chỗ để xe, gần chợ trường học, tt y tế, nhà mát liên hệ cô Tùng 0774253901', 'Price': '1.4 Triệu/tháng ', 'Square': '12m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n23/07/2022 '}
# 2022-11-29 16:04:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3>
#
# {'Id': '1511004', 'Title': 'Cho thuê phòng có máy lạnh, có gác, ful nội thất tại 654/32 Lạc Long Quân, P. 9, Q. Tân Bình (ngay ngã 4 Âu Cơ - Lạc Long Quân)', 'Price': '5 Triệu/tháng ', 'Square': '16m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n18/07/2022  '}
# 2022-11-29 16:04:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t3)
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1998701', 'Title': 'Phòng trọ bùi văn ba, gần kcx tân thuận, quận 7', 'Price': '3 Triệu/tháng ', 'Square': '15m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n06/07/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1998495', 'Title': 'Phòng trọ phạm văn hai, tân bình, giá rẻ 1,8 triệu.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n06/07/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1997666', 'Title': 'Cho thuê phòng trọ giá bình dân, quận tân bình, giá 1,8tr.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n05/07/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1997691', 'Title': 'Cho thuê phòng trọ giá rẻ quận tân bình, gần ngã tư bảy hiền.', 'Price': '1.8 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n05/07/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1991829', 'Title': 'Cho thuê phòng trọ quận tân bình, gần ngã tư bảy hiền, giá 2 triệu.', 'Price': '2 Triệu/tháng ', 'Square': '10m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n27/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1991844', 'Title': 'Cho thuê phòng trọ 71/20 Cô Giang, P.1, Q.Phú Nhuận, TP.HCM.', 'Price': '3 Triệu/tháng ', 'Square': '15m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n27/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1988733', 'Title': 'Cho thuê phòng trọ MỚI XÂY giá rẻ quận Bình Thạnh', 'Price': '4 Triệu/tháng ', 'Square': '18m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n23/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1985668', 'Title': 'Cho thuê phòng mới 100% số 36/66 Nguyễn Gia Trí, Bình Thạnh, giá tốt', 'Price': '2 Triệu/tháng ', 'Square': '6m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n20/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1850645', 'Title': 'Phòng cho thuê quận 8 khu an ninh có vệ sinh riêng giờ tự do', 'Price': '1.4 Triệu/tháng ', 'Square': '16m²', 'District': 'Quận 8', 'City': 'Hồ Chí Minh', 'Date': '\n18/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1979381', 'Title': 'Cho thuê phòng trọ 40m2, rộng rãi, an ninh', 'Price': '3.7 Triệu/tháng ', 'Square': '40m²', 'District': 'Quận 9', 'City': 'Hồ Chí Minh', 'Date': '\n13/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1756403', 'Title': 'Cho thuê phòng hiện đại Quận Gò Vấp - MỚI 100% chỉ 4tr/th (nhiều ưu đãi thêm & TL)', 'Price': '4 Triệu/tháng ', 'Square': '20m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n12/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1971009', 'Title': 'Phòng trọ hiện đại giá rẻ Huỳnh Tấn Phát, Quận 7', 'Price': '3.55 Triệu/tháng ', 'Square': '30m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n02/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1970198', 'Title': 'Cho thuê phòng tại đường ngô quyền, quận 10 giá chỉ từ 2.5tr/th lh 0938018851', 'Price': '2.5 Triệu/tháng ', 'Square': '12m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n01/06/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1968004', 'Title': 'Cho thuê phòng trọ đẹp số 36/66 Nguyễn Gia Trí, Bình Thạnh, giá tốt', 'Price': '2 Triệu/tháng ', 'Square': '6m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n30/05/2022 '}
# 2022-11-29 16:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4>
#
# {'Id': '1959067', 'Title': 'Cho thuê phòng trọ đường Trần Văn Kỷ Bình Thạnh gần ĐH Mỹ THuật', 'Price': '3.3 Triệu/tháng ', 'Square': '18m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n18/05/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t4)
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1926216', 'Title': 'Cho thuê phòng trọ phan xích long phú nhuận', 'Price': '4 Triệu/tháng ', 'Square': '20m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n28/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1723590', 'Title': 'Cho nữ thuê Phòng trọ quận Bình Thạnh, 25m2 mới đẹp, ban công, cửa sổ, hẻm 7m, xe tải vô tận nơi', 'Price': '4 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n26/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1943311', 'Title': 'Nhà trọ giá rẻ, mặt tiền đường, bếp - nhà VS - nước - bếp riêng biệt từng phòng', 'Price': '2.5 Triệu/tháng ', 'Square': '15m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n21/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1943027', 'Title': 'Phòng trọ gần đường Nguyễn Văn Lượng giá rẻ', 'Price': '3.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n21/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1938502', 'Title': 'Phòng có cửa sổ ánh sáng trời giá lại siểu rẻ tại P15, Tân Bình', 'Price': '3.5 Triệu/tháng ', 'Square': '28m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n15/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1936201', 'Title': 'Cần tìm 1 nữ ở ghép tại Nguyễn Hữu Cảnh. Giá 1,8 triệu', 'Price': '1 Triệu/tháng ', 'Square': '40m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n12/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1933881', 'Title': 'Cần gấp nữ ở ghép tại Bình Thạnh. 1.8triệu/ tháng', 'Price': '1 Triệu/tháng ', 'Square': '40m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n08/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1911291', 'Title': 'Phòng cao cấp Nguyễn Văn đậu full nội thất', 'Price': '5.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n08/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1933321', 'Title': 'Cho thuê phòng trọ KTX giá rẻ khu vực Q7,Q8,Bình Chánh...HCM', 'Price': '1.4 Triệu/tháng ', 'Square': '100m²', 'District': 'Bình Chánh', 'City': 'Hồ Chí Minh', 'Date': '\n07/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1932824', 'Title': 'Phòng trọ mới xây vừa hoàn công tại P.Tân Thới Nhất, Q12', 'Price': '2.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n07/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1933182', 'Title': 'Căn hộ studio cao cấp vào ở ngay tại P15, Tân Bình', 'Price': '3.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n07/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1931878', 'Title': 'Phòng trọ 30m2 cho gia đình, P.An Lạc, Q. Bình tân,', 'Price': '2.3 Triệu/tháng ', 'Square': '30m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n06/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1931557', 'Title': 'Phòng ban công thoáng mát tại Nguyễn Sỹ Sách, P15, Tân Bình', 'Price': '4.1 Triệu/tháng ', 'Square': '30m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n05/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1931061', 'Title': 'Trống phòng trọ mới, vừa hoàn công, còn mùi sơn tại Tân Thới Nhất, q12', 'Price': '2.6 Triệu/tháng ', 'Square': '30m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n05/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5>
#
# {'Id': '1931500', 'Title': 'Cho Thuê Phòng đủ tiện nghi Đường Lê trọng tấn 3.3 triệu', 'Price': '3.3 Triệu/tháng ', 'Square': '25m²', 'District': 'Tân Phú', 'City': 'Hồ Chí Minh', 'Date': '\n05/04/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t5)
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1927721', 'Title': 'Còn 1 phòng trọ có máy lạnh giá chỉ 3tr4', 'Price': '3.4 Triệu/tháng ', 'Square': '30m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n31/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1926961', 'Title': 'Phòng trống vào đầu tháng tại Đường số 19, Gò Vấp', 'Price': '3.2 Triệu/tháng ', 'Square': '30m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n30/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1926968', 'Title': 'Cho thuê mặt bằng tại Nguyễn Sỹ Sách, Tân Bình', 'Price': '11 Triệu/tháng ', 'Square': '70m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n30/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1927151', 'Title': 'Cho thuê phòng studio tại Nguyễn Sỹ Sách, Tân Bình', 'Price': '5.5 Triệu/tháng ', 'Square': '50m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n30/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1923585', 'Title': 'Cho thuê phòng trọ Q12 thoáng mát -20m2 đường Vườn Lài', 'Price': '1.2 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n25/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1923841', 'Title': 'Cho thuê nhà riêng 1 trệt 1 lầu, có ban công.', 'Price': '2.5 Triệu/tháng ', 'Square': '12.5m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n25/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1922595', 'Title': 'Phòng cao cấp đủ chỗ ở cho cả gia đình An Dương Vương, Q6', 'Price': '3.2 Triệu/tháng ', 'Square': '60m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n24/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1922749', 'Title': 'Còn 1 phòng giá rẻ 2tr9 ở Nguyễn Sỹ Sách, Tân Bình', 'Price': '2.9 Triệu/tháng ', 'Square': '28m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n24/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1922057', 'Title': 'Chung cư mini cao cấp, dạng phòng studio ở Ngô Tất Tố, Bình Thạnh', 'Price': '9 Triệu/tháng ', 'Square': '30m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n23/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1922142', 'Title': 'Phòng studio siêu xinh đầy đủ tiện nghi nội thất', 'Price': '5.5 Triệu/tháng ', 'Square': '35m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n23/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1921060', 'Title': 'Còn phòng trống ở Thống Nhất, Gò Vấp, TPHCM', 'Price': '3.2 Triệu/tháng ', 'Square': '30m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n22/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1921591', 'Title': 'Cho Thuê Phòng Trọ Công Nhân Giá Bình Dân', 'Price': '1.3 Triệu/tháng ', 'Square': '13m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n22/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1921452', 'Title': 'Cho thuê phòng trọ quận 10 giờ tự do không chung chủ', 'Price': '3.5 Triệu/tháng ', 'Square': '40m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n22/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1920812', 'Title': 'Phòng trọ giá rẻ Phạm Văn Chiêu, Gò Vấp.', 'Price': '3.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n21/03/2022 '}
# 2022-11-29 16:04:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6>
#
# {'Id': '1920814', 'Title': 'Cần tìm khách cho trọ Thống Nhất, Gò Vấp.', 'Price': '3.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n21/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t6)
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1918427', 'Title': 'CHDV Phan Đăng Lưu 6x12 có 3 Phòng ngủ giá 10 triệu/tháng', 'Price': '10 Triệu/tháng ', 'Square': '72m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n17/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1918452', 'Title': 'Chi tiết Gần Etown, Full NT, 4,7tr Ban công, Nước Nóng Lạnh', 'Price': '4.7 Triệu/tháng ', 'Square': '21m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n17/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1915080', 'Title': 'Phòng Studio 30m2 nội thất đẹp Lê Quang Định', 'Price': '6.5 Triệu/tháng ', 'Square': '30m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n12/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1914168', 'Title': 'Cho thuê phòng trọ diên tích 27 mét- 120/4 man thiện', 'Price': '3.2 Triệu/tháng ', 'Square': '27m²', 'District': 'Quận 9', 'City': 'Hồ Chí Minh', 'Date': '\n10/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1913999', 'Title': 'Cho thuê phòng Bùi Thị Xuân full Nội thất', 'Price': '4 Triệu/tháng ', 'Square': '18m²', 'District': 'Quận 1', 'City': 'Hồ Chí Minh', 'Date': '\n10/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1913364', 'Title': 'Cho Thuê Phòng Trọ Quận Phú Nhuận, Phường 13', 'Price': '3.2 Triệu/tháng ', 'Square': '30m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n09/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1913425', 'Title': 'Cần cho thuê nhà trọ 22.8 m2 giá rẻ chính chủ Huyện Nhà Bè', 'Price': '2.8 Triệu/tháng ', 'Square': '22.8m²', 'District': 'Nhà Bè', 'City': 'Hồ Chí Minh', 'Date': '\n09/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1913243', 'Title': 'Phòng Nguyễn Văn Đậu Full nội thất mới tinh', 'Price': '8.5 Triệu/tháng ', 'Square': '35m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n09/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1912992', 'Title': 'Phòng cho thuê dài hạn -sau lưng Nguyễn Kim Lê Văn Quới', 'Price': '4.8 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n08/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1910874', 'Title': 'Cho thuê phòng giá rẻ - Trần Đại Nghĩa - Bình Tân', 'Price': '1.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Tân', 'City': 'Hồ Chí Minh', 'Date': '\n04/03/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1907031', 'Title': 'CHDV Nguyễn Văn Đậu 30m2 full nội thất 7,5 triệu', 'Price': '7.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n24/02/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1905358', 'Title': 'Phòng Bùi Đình Túy Full nội thất 25m2 Thang máy', 'Price': '5.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n21/02/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1904339', 'Title': 'Cho thuê chung cư mini giá rẻ-Đ.phan huy ích P14- Q. gò vấp, giá : 2,4 triệu/tháng', 'Price': '2.4 Triệu/tháng ', 'Square': '25m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n18/02/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1903486', 'Title': 'Cho thuê phòng trọ giá rẻ, dt 10m2 giá 1,3 triệu tại 121/8 khu phố 8 đường tân chánh hiệp 10 quận 12', 'Price': '1.3 Triệu/tháng ', 'Square': '10m²', 'District': 'Quận 12', 'City': 'Hồ Chí Minh', 'Date': '\n16/02/2022 '}
# 2022-11-29 16:04:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7>
#
# {'Id': '1902877', 'Title': 'Cho thuê phòng ở 19 Trương văn Thành, P.Hiệp phú, TP Thủ đức', 'Price': '2.2 Triệu/tháng ', 'Square': '13m²', 'District': 'Quận 9', 'City': 'Hồ Chí Minh', 'Date': '\n15/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t7)
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1901273', 'Title': 'Cho Thuê phòng trọ 18m2 đường Âu dương Lân, Q8', 'Price': '2.5 Triệu/tháng ', 'Square': '18m²', 'District': 'Quận 8', 'City': 'Hồ Chí Minh', 'Date': '\n10/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1901035', 'Title': 'Phòng full nội thất cạnh dh ngoại thương-hutech', 'Price': '5.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n09/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1901040', 'Title': 'Còn 2 Phòng trọ ở 243A/58 đường Hoàng Diệu, Phường 8, Quận 4, Hồ Chí Minh', 'Price': '2.7 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 4', 'City': 'Hồ Chí Minh', 'Date': '\n09/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1900587', 'Title': 'Phòng trọ Gò Vấp thoáng mát gần các khu vực tiện lợi', 'Price': '2.1 Triệu/tháng ', 'Square': '13m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n07/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1900431', 'Title': 'Cho thuê phòng trọ tại hém 18, đường số 8, P. Linh Xuân, Q. Thủ đức', 'Price': '1.2 Triệu/tháng ', 'Square': '12m²', 'District': 'Thủ Đức', 'City': 'Hồ Chí Minh', 'Date': '\n06/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1900328', 'Title': 'Phòng Bùi Đình Túy Full nội thất 25m2 có thang máy', 'Price': '5 Triệu/tháng ', 'Square': '20m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n05/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1900338', 'Title': 'Phòng trọ chu văn an bình thạnh, trệt + gác, từ 16m2, từ 2tr', 'Price': '2 Triệu/tháng ', 'Square': '16m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n05/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1900340', 'Title': 'Phòng trọ đinh bộ lĩnh bình thạnh, trệt + gác, từ 16m2, từ 2tr', 'Price': '2 Triệu/tháng ', 'Square': '16m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n05/02/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1896947', 'Title': 'Phòng ban công-lộng gió cạnh landmark81-hxh', 'Price': '4.5 Triệu/tháng ', 'Square': '25m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n15/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1896949', 'Title': 'Phòng ban công-lộng gió gò vấp-hxh an ninh', 'Price': '3.9 Triệu/tháng ', 'Square': '24m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n15/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1895717', 'Title': 'Phòng trọ Q9 gần Sân gold, Suối Tiên, làng đại học Quốc Gia', 'Price': '2.7 Triệu/tháng ', 'Square': '24m²', 'District': 'Quận 9', 'City': 'Hồ Chí Minh', 'Date': '\n13/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1894301', 'Title': 'Cần Cho Thuê Phòng Điện Nước Wifi miễn phí, Giờ Giấc Tự Do', 'Price': '2 Triệu/tháng ', 'Square': '20m²', 'District': 'Bình Chánh', 'City': 'Hồ Chí Minh', 'Date': '\n10/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1894366', 'Title': 'Cho thuê Phòng trọ 35m _ 40m2 đường số 9 dãi nhà phố khu cityland Park, p10', 'Price': '4.5 Triệu/tháng ', 'Square': '35m²', 'District': 'Gò Vấp', 'City': 'Hồ Chí Minh', 'Date': '\n10/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1891870', 'Title': 'Phòng (Ban công + Cửa sổ thoáng mát), trung tâm Phú Nhuận', 'Price': '2.9 Triệu/tháng ', 'Square': '15m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n05/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8>
#
# {'Id': '1891110', 'Title': 'Cho thuê phòng tại số 6 đường nguyễn biểu, phường 1, quận 5, tp. Hồ chí minh', 'Price': '6.5 Triệu/tháng ', 'Square': '20m²', 'District': 'Quận 5', 'City': 'Hồ Chí Minh', 'Date': '\n04/01/2022 '}
# 2022-11-29 16:04:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t9> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t8)
# 2022-11-29 16:04:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t9>
#
# ...
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1274895', 'Title': 'PHÒNG TRỌ NGAY ĐƯỜNG LÊ VĂN LƯƠNG, QUẬN 7, MỚI XÂY, THOÁNG MÁT, CÓ BẢO VỆ, CÓ THANG MÁY', 'Price': '3.8 Triệu/tháng', 'Square': '25 m²', 'District': 'Nhà Bè', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1271828', 'Title': 'Cho thuê phòng full nội thất, ngay trung tâm TP.HCM.', 'Price': '6.5 Triệu/tháng', 'Square': '27 m²', 'District': 'Quận 3', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1271578', 'Title': 'Chính Chủ Cho Thuê Phòng Trọ Đường Hồng Hà. Ngay Sân Bay.Gía 4.5Tr/Tháng', 'Price': '4.5 Triệu/tháng', 'Square': '25 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1272092', 'Title': 'Cho thuê phòng trọ dịch vụ sẵn nội thất ngay trung tâm Bình Thạnh', 'Price': '7 Triệu/tháng', 'Square': '30 m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1271880', 'Title': 'Cho Thuê phòng ở tại B214/8 Bạch đằng P2 Tân bình, TPHCM gần sân bay TSN.', 'Price': '4.5 Triệu/tháng', 'Square': '20 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1272399', 'Title': 'Cho thuê phòng cao cấp full nội thất đường Yên Thế quận Tân Bình giá 4.5tr/tháng', 'Price': '4.5 Triệu/tháng', 'Square': '20 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1273682', 'Title': 'Phòng MỚI, WC RIÊNG, CÓ BẢO VỆ- gần Võ Văn Kiệt, An Dương Vương, Q.8', 'Price': '2.5 Triệu/tháng', 'Square': '18 m²', 'District': 'Quận 8', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226>
#
# {'Id': '1271893', 'Title': 'CHO THUÊ PHÒNG TRỌ MỚI XÂY NGAY ĐƯỜNG CHỮ ĐỒNG TỬ, Q. TÂN BÌNH, CÓ KỆ BẾP', 'Price': '4.5 Triệu/tháng', 'Square': '25 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t226)
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1271719', 'Title': 'CHO THUÊ PHÒNG TRỌ MỚI XÂY NGAY ĐƯỜNG NƠ TRANG LONG, Q. BÌNH THẠNH', 'Price': '4.5 Triệu/tháng', 'Square': '25 m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1269431', 'Title': 'PHÒNG Ở GIA ĐÌNH ĐIỆN NƯỚC RIÊNG, ĐẦY ĐỦ NỘI THẤT, WIFE FREE, GIỜ TỰ DO', 'Price': '3 Triệu/tháng', 'Square': '35 m²', 'District': 'Quận 6', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1271485', 'Title': 'CHO THUÊ CĂN HỘ MINI NGAY ĐƯỜNG LÊ VĂN LƯƠNG, QUẬN 7, CÓ BAN CÔNG, CÓ BẢO VỆ 24/24', 'Price': '3.8 Triệu/tháng', 'Square': '25 m²', 'District': 'Nhà Bè', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1274562', 'Title': 'Cho thuê phòng trọ có ban công view Landmark 81, sau lưng Pearl Plaza Điện Biên Phủ', 'Price': '5 Triệu/tháng', 'Square': 'Không xác định', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1274583', 'Title': 'Phòng cho thuê ngay trung tâm Nguyễn Trải Quận 1 . Gần chợ Bến Thành, Bùi Viện .4.5tr/th 0902844313', 'Price': '4.5 Triệu/tháng', 'Square': 'Không xác định', 'District': 'Quận 1', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1272282', 'Title': 'PHÒNG ĐẦY ĐỦ TIỆN NGHI - NGAY QUẬN TÂN BÌNH, ĐƯỜNG CỘNG HOÀ, GẦN SÂN BAY', 'Price': '5.5 Triệu/tháng', 'Square': '28 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n22/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1268227', 'Title': 'Cho thuê phòng trọ cao cấp khu vực sân bay, Phú Nhuận', 'Price': '5.5 Triệu/tháng', 'Square': '18 m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1267731', 'Title': 'Cho thuê phòng ngay gần Ngã 4 Phú Nhuận, giờ giấc tự do', 'Price': '2 Triệu/tháng', 'Square': '11 m²', 'District': 'Phú Nhuận', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1264405', 'Title': 'CHO THUÊ CĂN HỘ MINI FULL TIỆN NGHI NGAY ĐƯỜNG NGUYỄN CỬU VÂN, BÌNH THẠNH', 'Price': '6 Triệu/tháng', 'Square': '25 m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1268253', 'Title': 'Cho thuê phòng đầy đủ tiện nghi ngay trung tâm Q7 giá từ 4,5tr/tháng LH : Anh Long ', 'Price': '4.5 Triệu/tháng', 'Square': '45 m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1269026', 'Title': 'CHO THUÊ PHÒNG BÌNH THẠNH, NGAY CHỢ BÀ CHIỂU - CÓ THANG MÁY, BẢO VỆ 24/24, 25m2 Giá 4,5tr/m2', 'Price': '4.5 Triệu/tháng', 'Square': 'Không xác định', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1264164', 'Title': 'Phòng đẹp Lê Văn Sỹ gần Trần Quang Diệu nhà biệt thự, nội thất cao cấp bảo vệ 24/24 giá 6.5 tỷ', 'Price': '6.5 Triệu/tháng', 'Square': '30 m²', 'District': 'Quận 3', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1268009', 'Title': 'Cho Thuê Phòng Trọ Cao Cấp Ngay Hoàng Sa, Trường Sa', 'Price': '5 Triệu/tháng', 'Square': '25 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1267504', 'Title': 'Phòng trọ kí túc xá giá rẻ 700k/tháng tại Tân bình', 'Price': '7 Trăm nghìn/tháng', 'Square': '25 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227>
#
# {'Id': '1267266', 'Title': 'Cho thuê phòng gần bệnh viện Mỹ Đức đường Núi Thành. LH: 0938 118 438', 'Price': 'Thương lượng', 'Square': '14 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227)
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1264248', 'Title': 'CHO THUÊ PHÒNG TRỌ NGAY ĐƯỜNG LÊ VĂN LƯƠNG, QUẬN 7, FULL NỘI THẤT, GIÁ RẺ', 'Price': '5.3 Triệu/tháng', 'Square': '30 m²', 'District': 'Nhà Bè', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1264765', 'Title': 'Phòng Trọ Có Ban Công Ngay Ngã Tư Hàng Xanh', 'Price': '5.8 Triệu/tháng', 'Square': '30 m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1263998', 'Title': 'Nhà nguyên căn hoàn toàn mới cần cho thuê mặt bằng và căn hộ dịch vụ cao cấp - khu K300', 'Price': '3.8 Triệu/tháng', 'Square': '20 m²', 'District': 'Tân Bình', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1263756', 'Title': 'Phòng trọ thoáng mát ở trung tâm quận 10 đường Thành Thái', 'Price': '3 Triệu/tháng', 'Square': '20 m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1269397', 'Title': ' PHÒNG LỚN 35 M2 ĐẦY ĐỦ NỘI THẤT , ĐIỆN NƯỚC RIÊNG, WIFI FREE, GIÁ 3 TRIỆU BAO ĐẬU XE', 'Price': '3 Triệu/tháng', 'Square': '35 m²', 'District': 'Quận 6', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1263796', 'Title': 'Cho thuê Ký Túc Xá Phòng Máy Lạnh Cao Cấp ngay ĐH Bách Khoa Q10 LH : Mr Thiên Ban', 'Price': '1.6 Triệu/tháng', 'Square': '25 m²', 'District': 'Quận 10', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1265118', 'Title': 'Phòng trọ 30m2 có gác, sạch sẽ, hẻm xe hơi, tại Xô Viết Nghệ Tĩnh, Bình Thạnh. Giờ tự do, an ninh', 'Price': '3.2 Triệu/tháng', 'Square': '30 m²', 'District': 'Bình Thạnh', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1264352', 'Title': 'Phòng khách sạn cho thuê dài hạn full nội thất ,nhà MT ngay chợ tân mỹ ,quận 7', 'Price': '3.5 Triệu/tháng', 'Square': '15 m²', 'District': 'Quận 7', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228>
#
# {'Id': '1268970', 'Title': 'Phòng 40m2, có BAN CÔNG, gần ĐH Luật, ĐH Văn Lang,.. giá 3.2TR', 'Price': '3.2 Triệu/tháng', 'Square': '40 m²', 'District': 'Thủ Đức', 'City': 'Hồ Chí Minh', 'Date': '\n21/12/2018 '}
# 2022-11-29 16:09:42 [scrapy.core.scraper] ERROR: Spider error processing <GET https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t228> (referer: https://ancu.me/cho-thue-nha-tro-phong-tro-thanh-pho-ho-chi-minh/t227)
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\defer.py", line 240, in iter_errback
#     yield next(it)
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 338, in __next__
#     return next(self.data)
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 338, in __next__
#     return next(self.data)
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 79, in process_sync
#     for r in iterable:
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 79, in process_sync
#     for r in iterable:
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 336, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 79, in process_sync
#     for r in iterable:
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 79, in process_sync
#     for r in iterable:
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 32, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 79, in process_sync
#     for r in iterable:
#   File "c:\Users\HP\OneDrive - VNU-HCMUS\Documents\GitHub\NM-KHDL\project_code\colect_data\colect_data\spiders\colect_data.py", line 26, in parse
#     Id = Id[Id.index('-ad')+3:Id.index('.html')]
# AttributeError: 'NoneType' object has no attribute 'index'
# 2022-11-29 16:09:42 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-11-29 16:09:42 [scrapy.extensions.feedexport] INFO: Stored csv feed (3414 items) in: dataset/inf.csv
# 2022-11-29 16:09:42 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 134872,
#  'downloader/request_count': 229,
#  'downloader/request_method_count/GET': 229,
#  'downloader/response_bytes': 5071104,
#  'downloader/response_count': 229,
#  'downloader/response_status_count/200': 229,
#  'elapsed_time_seconds': 299.362789,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 11, 29, 9, 9, 42, 456404),
#  'httpcompression/response_bytes': 24284910,
#  'httpcompression/response_count': 229,
#  'item_scraped_count': 3414,
#  'log_count/DEBUG': 3648,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 15,
#  'log_count/WARNING': 1,
#  'request_depth_max': 227,
#  'response_received_count': 229,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 228,
#  'scheduler/dequeued/memory': 228,
#  'scheduler/enqueued': 228,
#  'scheduler/enqueued/memory': 228,
#  'spider_exceptions/AttributeError': 1,
#  'start_time': datetime.datetime(2022, 11, 29, 9, 4, 43, 93615)}
# 2022-11-29 16:09:42 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# <h1><b>B. Khám phá dữ liệu (đan xen với tiền xử lý dữ liệu)</b></h1>

# %% [markdown]
# ### Đọc dữ liệu từ tập tin (file)
#
# Đầu tiên, Đọc dữ liệu từ file "inf.csv" và lưu kết quả vào DataFrame df_info.

# %%
df_info = pd.read_csv('./colect_data/colect_data/dataset/inf.csv')
df_info = df_info.set_index('Id').sort_index()
df_info.head()
# Out:
#                                                   Title            Price  \
# Id
# 329   Tìm người ở ghép phòng trọ gần ngã 3 Lũy Bán B...  8.4 Triệu/tháng
# 1110  Cho thuê phòng trọ 25m2, giờ tự do hẻm 137 Trị...  2.5 Triệu/tháng
# 1114  Chuyên cho thuê CH Era Town có thể dọn vào ở l...    2 Triệu/tháng
# 1275  Phòng gác lửng, máy lạnh, ban công, WC riêng, ...  3.7 Triệu/tháng
# 1592  Cho thuê phòng full nội thất cho nữ trong căn ...  3.8 Triệu/tháng
#
#               Square District         City           Date
# Id
# 329   Không xác định  Tân Phú  Hồ Chí Minh  \n17/05/2018
# 1110           25 m²  Tân Phú  Hồ Chí Minh  \n14/05/2018
# 1114           15 m²   Quận 7  Hồ Chí Minh  \n14/05/2018
# 1275  Không xác định   Quận 7  Hồ Chí Minh  \n14/05/2018
# 1592  Không xác định   Nhà Bè  Hồ Chí Minh  \n14/05/2018

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột

# %%
df_info.shape
# Out:
# (3414, 6)

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng trong DataFrame `df_info` cho biết thông tin của nhà trọ phòng trọ cho thuê. Có vẻ không có vấn đề các dòng có ý nghĩa khác nhau.

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không?

# %% [markdown]
# Ta sẽ xem thử rằng trong tập có dòng nào bị trùng không. Nếu trùng thì trả về True, không thì là False và lưu số dòng trùng vào biến num_duplicated_rows

# %%
#Tính tổng dòng lặp
num_duplicated_rows = df_info.duplicated().sum()
is_duplicated = (num_duplicated_rows != 0)
print(num_duplicated_rows)
print(is_duplicated)
# Out:
# 0
# False

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì?
#
# Ý nghĩa của mỗi cột là:
#
# - **ID** là để phân biệt phòng trọ, nhà trọ.
#
# - **Title** là tiêu đề của phòng trọ, nhà trọ.
#
# - **Price** là giá cho thuê của phòng trọ, nhà trọ theo tháng, đơn vị là VNĐ.
#
# - **Square** là diện tích của phòng trọ, nhà trọ, đơn vị là $m^2$.
#
# - **District** là địa chỉ quận của phòng trọ, nhà trọ.
#
# - **City** là địa chỉ thành phố của phòng trọ, nhà trọ.
#
# - **Date** là ngày đăng tin cho thuê của phòng trọ, nhà trọ.

# %%
df_info.columns
# Out:
# Index(['Title', 'Price', 'Square', 'District', 'City', 'Date'], dtype='object')

# %% [markdown]
# Ta kiểm tra dạng dữ liệu của các cột để xem có đúng với dạng mà ta mong muốn không.

# %%
df_info.dtypes
# Out:
# Title       object
# Price       object
# Square      object
# District    object
# City        object
# Date        object
# dtype: object

# %% [markdown]
# Ta thấy các cột đều ở dạng object, điều này là không nên bởi vì nếu cột nào cũng ở dạng object thì rất khó tính toán. Ta thấy rằng có 3 cột có thể chuyển sang dạng khác là Price (numeric), Square (numeric), Date (datetime). Ta sẽ tiến hành chuyển dạng của các cột này

# %% [markdown]
# Đầu tiên là cột Square, ta sẽ coi thử giá trị của nó

# %%
df_info["Square"]
# Out:
# Id
# 329        Không xác định
# 1110                25 m²
# 1114                15 m²
# 1275       Không xác định
# 1592       Không xác định
#                 ...
# 2112161              25m²
# 2113773              20m²
# 2118730              30m²
# 2119311              16m²
# 2122158              20m²
# Name: Square, Length: 3414, dtype: object

# %% [markdown]
# Ta thấy rằng các giá trị đều có m² ở sau, ta loại bỏ và chuyển nó sang dạng số

# %%
df_info["Square"] =df_info["Square"].str.replace('m²','')
df_info["Square"] = pd.to_numeric(df_info["Square"],errors='coerce')
df_info.rename(columns={'Square':'Square(m²)'},inplace=True)

# %% [markdown]
# Ta thấy rằng cột Price có thể chuyển sang dạng số, như vậy ta sẽ xử lý nó, đem nó về dạng số với đơn vị là TriệuVNĐ/tháng
#
# Ta sẽ xem qua các giá trị của cột này

# %%
df_info["Price"]
# Out:
# Id
# 329         8.4 Triệu/tháng
# 1110        2.5 Triệu/tháng
# 1114          2 Triệu/tháng
# 1275        3.7 Triệu/tháng
# 1592        3.8 Triệu/tháng
#                  ...
# 2112161    2.8 Triệu/tháng
# 2113773    5.5 Triệu/tháng
# 2118730    2.8 Triệu/tháng
# 2119311      5 Triệu/tháng
# 2122158    2.5 Triệu/tháng
# Name: Price, Length: 3414, dtype: object

# %% [markdown]
# Ta thấy rằng sau giá thường có đơn vị như Triệu/tháng,... ta sẽ coi cụ thể hơn các giá trị để tiện xử lý

# %%
df_info["Price"].unique()
# Out:
# array(['8.4 Triệu/tháng', '2.5 Triệu/tháng', '2 Triệu/tháng',
#        '3.7 Triệu/tháng', '3.8 Triệu/tháng', '9 Triệu/tháng',
#        '3 Triệu/tháng', '3.5 Triệu/tháng', '3.2 Triệu/tháng',
#        '3.3 Triệu/tháng', '5.6 Triệu/tháng', '5 Triệu/tháng',
#        '5.5 Triệu/tháng', '3.4 Triệu/tháng', '1 Triệu/tháng',
#        '6.2 Triệu/tháng', '2.8 Triệu/tháng', '6.5 Triệu/tháng',
#        'Thương lượng', '4.2 Triệu/tháng', '15 Triệu/tháng',
#        '2.3 Triệu/tháng', '4 Triệu/tháng', '6.7 Triệu/tháng',
#        '1.4 Triệu/tháng', '9.5 Triệu/tháng', '7.5 Triệu/tháng',
#        '3.9 Triệu/tháng', '4.5 Triệu/tháng', '10 Triệu/tháng',
#        '1.7 Triệu/tháng', '7 Triệu/tháng', '4 Trăm nghìn/tháng',
#        '2.6 Triệu/tháng', '2.7 Triệu/tháng', '1.5 Triệu/tháng',
#        '8 Triệu/tháng', '2.99 Triệu/tháng', '6 Trăm nghìn/tháng',
#        '6 Triệu/tháng', '2.2 Triệu/tháng', '4.8 Triệu/tháng',
#        '12 Triệu/tháng', '1.8 Triệu/tháng', '4.9 Triệu/tháng',
#        '4.6 Triệu/tháng', '5.8 Triệu/tháng', '5 Trăm nghìn/tháng',
#        '6.8 Triệu/tháng', '15.94 Triệu/tháng', '6.5 Trăm nghìn/tháng',
#        '2.9 Triệu/tháng', '5.7 Triệu/tháng', '1.3 Triệu/tháng',
#        '1.2 Triệu/tháng', '9.027 Triệu/tháng', '3.6 Triệu/tháng',
#        '4.7 Triệu/tháng', '2.4 Triệu/tháng', '15 Trăm nghìn/tháng',
#        '1.9 Triệu/tháng', '4.3 Triệu/tháng', '6.3 Triệu/tháng',
#        '4.964 Triệu/tháng', '2.1 Triệu/tháng', '8.5 Triệu/tháng',
#        '800 Trăm nghìn/tháng', '7.5 Trăm nghìn/tháng',
#        '8 Trăm nghìn/tháng', '4.4 Triệu/tháng', '1.6 Triệu/tháng',
#        '12.59 Triệu/tháng', '19 Triệu/tháng', '1.1 Triệu/tháng',
#        '5.1 Triệu/tháng', '5.9 Triệu/tháng', '9 Trăm nghìn/tháng',
#        '5.2 Triệu/tháng', '7.9 Triệu/tháng', '10.5 Triệu/tháng',
#        '5.3 Triệu/tháng', '1.47 Triệu/tháng', '67 Triệu/tháng',
#        '4.5 Trăm nghìn/tháng', '6.6 Triệu/tháng', '7 Trăm nghìn/tháng',
#        '56 Triệu/tháng', '1.29 Triệu/tháng', '4.1 Triệu/tháng',
#        '68 Trăm nghìn/tháng', '3.1 Triệu/tháng', '45 Trăm nghìn/tháng',
#        '5 Triệu/m2/tháng', '25 Triệu/tháng', '37 Trăm nghìn/tháng',
#        '55 Trăm nghìn/tháng', '1.25 Triệu/tháng', '35 Trăm nghìn/tháng',
#        '6.3 Trăm nghìn/tháng', '35 Triệu/tháng', '43 Trăm nghìn/tháng',
#        '2.3 Triệu/tháng ', '3.5 Triệu/tháng ', '3.8 Triệu/tháng ',
#        '1.2 Triệu/tháng ', '2.5 Triệu/tháng ', '1 Triệu/tháng ',
#        '2 Triệu/tháng ', '1000000 Triệu/tháng ', '25 Trăm nghìn/tháng',
#        '7.5 Trăm nghìn/m2/tháng', '7.2 Triệu/tháng', '6.5 Triệu/tháng ',
#        '8.5 Trăm nghìn/tháng', '9.9 Trăm nghìn/tháng',
#        '73 Trăm nghìn/tháng', '22 Trăm nghìn/tháng',
#        '30 Trăm nghìn/tháng', '1.4 Triệu/tháng ', '1.3 Triệu/tháng ',
#        '1.1 Triệu/tháng ', '1.5 Triệu/tháng ', '1.35 Triệu/tháng',
#        '4.65 Triệu/tháng', '450 Trăm nghìn/tháng', '11.5 Triệu/tháng',
#        '2.65 Triệu/tháng', '780 Triệu/tháng', '4500 Triệu/tháng',
#        '6.5 Triệu/m2/tháng', '32 Trăm nghìn/tháng', '11 Triệu/tháng',
#        '6 Triệu/tháng ', '4.5 Triệu/tháng ', '2.9 Triệu/tháng ',
#        '1.45 Triệu/tháng ', '1.75 Triệu/tháng', '36 Trăm nghìn/tháng',
#        '3 Triệu/tháng ', '4 Triệu/tháng ', '2.2 Triệu/tháng ',
#        '1.7 Triệu/tháng ', '7.6 Triệu/tháng', '38 Trăm nghìn/tháng',
#        '1.6 Triệu/tháng ', '2.6 Triệu/tháng ', '4.2 Triệu/tháng ',
#        '3500 Triệu/tháng ', '14 Triệu/tháng', '2.7 Triệu/tháng ',
#        '6.1 Triệu/tháng', '40 Trăm nghìn/tháng', '2.8 Triệu/tháng ',
#        '1.8 Triệu/tháng ', '0.45 Triệu/tháng ', '5 Triệu/tháng ',
#        '35 Triệu/tháng ', '3.2 Triệu/tháng ', '3.7 Triệu/tháng ',
#        '1.9 Triệu/tháng ', '950 Nghìn/m2/tháng', '3.6 Triệu/tháng ',
#        '5.5 Triệu/tháng ', '0.002 Triệu/tháng ', '50 Trăm nghìn/tháng',
#        '18 Trăm nghìn/tháng', '23 Trăm nghìn/tháng', '2.1 Triệu/tháng ',
#        '0.8 Triệu/tháng ', '8 Triệu/tháng ', '7 Triệu/tháng ',
#        '0.9 Triệu/tháng ', '2.95 Triệu/tháng ', '10 Triệu/tháng ',
#        '0.7 Triệu/tháng ', '28 Triệu/tháng ', '4.8 Triệu/tháng ',
#        '3000000 Triệu/tháng ', '3.1 Triệu/tháng ', '1600000 Triệu/tháng ',
#        '1500000 Triệu/tháng ', '4.3 Triệu/tháng ', '1.15 Triệu/tháng ',
#        '7.5 Triệu/tháng ', '12 Triệu/tháng ', '8.5 Triệu/tháng ',
#        '24 Triệu/tháng ', '23 Triệu/tháng ', '1.02 Triệu/tháng ',
#        '25 Triệu/tháng ', '32 Triệu/tháng ', '27 Triệu/tháng ',
#        '3.3 Triệu/tháng ', '0.6 Triệu/tháng ', '2.99 Triệu/tháng ',
#        '350 Triệu/tháng ', '5.9 Triệu/tháng ', '6.3 Triệu/tháng ',
#        '5.8 Triệu/tháng ', '2.4 Triệu/tháng ', '13 Triệu/tháng ',
#        '0.001 Triệu/tháng ', '0.75 Triệu/tháng ', '50.005 Triệu/tháng ',
#        '0.23 Triệu/tháng ', '0 Triệu/tháng ', '3.4 Triệu/tháng ',
#        '4.6 Triệu/tháng ', '5.2 Triệu/tháng ', '50 Triệu/tháng ',
#        '305 Triệu/tháng ', '3.35 Triệu/tháng ', '1.85 Triệu/tháng ',
#        '5.3 Triệu/tháng ', '4.1 Triệu/tháng ', '3.05 Triệu/tháng ',
#        '1.004 Triệu/tháng ', '2.45 Triệu/tháng ', '1.65 Triệu/tháng ',
#        '5.7 Triệu/tháng ', '0.5 Triệu/tháng ', '3.9 Triệu/tháng ',
#        '0.65 Triệu/tháng ', '4.7 Triệu/tháng ', '6.8 Triệu/tháng ',
#        '11 Triệu/tháng ', '7.2 Triệu/tháng ', '60 Triệu/tháng ',
#        '3.005 Triệu/tháng ', '9 Triệu/tháng ', '3.55 Triệu/tháng ',
#        '4.9 Triệu/tháng ', '1.35 Triệu/tháng '], dtype=object)

# %% [markdown]
# Ta thấy có các dạng đơn vị là Triệu/tháng, Trăm nghìn/tháng, Triệu/m2/tháng, Trăm nghìn/m2/tháng, Nghìn/m2/tháng  và có thêm một kiểu giá trị là Thương lượng. Ta sẽ chuyển toàn bộ đơn vị sang Triệu/tháng và loại bỏ đơn vị ở sau để tiện chuyển nó thành số, riêng giá trị Thương lượng thì ta sẽ để là NaN

# %%
def convert_price(price,square):
    if 'Triệu/tháng' in price:
        price = price.replace('Triệu/tháng','')
        return float(price)
    if 'Trăm nghìn/tháng' in price:
        price = price.replace('Trăm nghìn/tháng','')
        return float(price)/10
    if 'Triệu/m2/tháng' in price:
        if pd.isna(square):
            return np.nan
        price = price.replace('Triệu/m2/tháng','')
        return float(price)*square
    if 'Trăm nghìn/m2/tháng' in price:
        if pd.isna(square):
            return np.nan
        price = price.replace('Trăm nghìn/m2/tháng','')
        price = float(price)/10
        return price*square
    if 'Nghìn/m2/tháng' in price:
        if pd.isna(square):
            return np.nan
        price = price.replace('Nghìn/m2/tháng','')
        price = float(price)/1000
        return price*square
    return np.nan


df_price_square = df_info[['Price','Square(m²)']]

for i in df_price_square.index:
    df_price_square['Price'][i] = convert_price(df_price_square['Price'][i],df_price_square['Square(m²)'][i])
    
df_info['Price'] =  pd.to_numeric(df_price_square['Price'])
df_info.rename(columns={'Price':'Price(Triệu/tháng)'},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6840\3810743824.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_square['Price'][i] = convert_price(df_price_square['Price'][i],df_price_square['Square(m²)'][i])

# %% [markdown]
# Coi lại giá trị của cột này

# %%
df_info["Price(Triệu/tháng)"]
# Out:
# Id
# 329        8.4
# 1110       2.5
# 1114       2.0
# 1275       3.7
# 1592       3.8
#           ...
# 2112161    2.8
# 2113773    5.5
# 2118730    2.8
# 2119311    5.0
# 2122158    2.5
# Name: Price(Triệu/tháng), Length: 3414, dtype: float64

# %% [markdown]
# Ở cột Date, ta thấy tui là nó biểu diễn ngày tháng năm nhưng lại không có dạng dữ liệu là datetime mà là object, ta cũng sẽ xử lý trường hợp này

# %%
#Coi dữ liệu của cột Date
df_info["Date"]
# Out:
# Id
# 329        \n17/05/2018
# 1110       \n14/05/2018
# 1114       \n14/05/2018
# 1275       \n14/05/2018
# 1592       \n14/05/2018
#                ...
# 2112161    \n15/11/2022
# 2113773    \n17/11/2022
# 2118730    \n24/11/2022
# 2119311    \n25/11/2022
# 2122158    \n29/11/2022
# Name: Date, Length: 3414, dtype: object

# %% [markdown]
# Dữ liệu của cột này có dư kí tự '\n', vậy ta cần phải loại bỏ trước khi chuyển dạng của nó

# %%
df_info["Date"] = df_info["Date"].str.replace('\n','')
pd.to_datetime(df_info["Date"],format = "%d/%m/%Y ",errors = 'coerce')
# Out:
# Id
# 329       2018-05-17
# 1110      2018-05-14
# 1114      2018-05-14
# 1275      2018-05-14
# 1592      2018-05-14
#              ...
# 2112161   2022-11-15
# 2113773   2022-11-17
# 2118730   2022-11-24
# 2119311   2022-11-25
# 2122158   2022-11-29
# Name: Date, Length: 3414, dtype: datetime64[ns]

# %%
df_info["Date"]
# Out:
# Id
# 329        17/05/2018
# 1110       14/05/2018
# 1114       14/05/2018
# 1275       14/05/2018
# 1592       14/05/2018
#               ...
# 2112161    15/11/2022
# 2113773    17/11/2022
# 2118730    24/11/2022
# 2119311    25/11/2022
# 2122158    29/11/2022
# Name: Date, Length: 3414, dtype: object

# %%
df_info.to_csv('clean_data.csv')
